# %%
import pandas as pd
import numpy as np
data = pd.read_csv("COVID19 data for overall INDIA.csv")
print(data.head())
# Out:
#               Date    Date_YMD  Daily Confirmed  Daily Deceased
# 0  30 January 2020  2020-01-30                1               0
# 1  31 January 2020  2020-01-31                0               0
# 2  1 February 2020  2020-02-01                0               0
# 3  2 February 2020  2020-02-02                1               0
# 4  3 February 2020  2020-02-03                1               0

# %%
data.isnull().sum()
# Out:
# Date               0
# Date_YMD           0
# Daily Confirmed    0
# Daily Deceased     0
# dtype: int64

# %%
data = data.drop("Date", axis=1)

# %%
import plotly.express as px
fig = px.bar(data, x='Date_YMD', y='Daily Confirmed',labels={'Date_YMD': 'Date', 'Daily Confirmed': 'Number of Cases'},
             width=600,  
             height=300)
fig.show()

# %%
cases = data["Daily Confirmed"].sum()
deceased = data["Daily Deceased"].sum()

labels = ["Confirmed", "Deceased"]
values = [cases, deceased]

fig = px.pie(data, values=values, 
             names=labels, 
             title='Daily Confirmed Cases vs Daily Deaths', hole=0.3)
fig.show()

# %%
death_rate = (data["Daily Deceased"].sum() / data["Daily Confirmed"].sum()) * 100
print(death_rate)
# Out:
# 1.2840580507834722

# %%
import plotly.express as px
fig = px.bar(data, x='Date_YMD', y='Daily Deceased' ,labels={'Date_YMD': 'Date', 'Daily Deceased': 'Number of Deaths'},
             width=600,  
             height=300)
fig.show()

# %%
pip install autots
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from autots import AutoTS
model = AutoTS(forecast_length=30, frequency='infer', ensemble='simple')
model = model.fit(data, date_col="Date_YMD", value_col='Daily Deceased', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# Using 1 cpus for n_jobs.
# Data frequency is: D, used frequency is: D
# Model Number: 1 with model ARIMA in generation 0 of 20
# Model Number: 2 with model AverageValueNaive in generation 0 of 20
# Model Number: 3 with model AverageValueNaive in generation 0 of 20
# Model Number: 4 with model AverageValueNaive in generation 0 of 20
# Model Number: 5 with model DatepartRegression in generation 0 of 20
# Model Number: 6 with model DatepartRegression in generation 0 of 20
# Model Number: 7 with model DatepartRegression in generation 0 of 20
# C:\Users\MICRO\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1235: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# C:\Users\MICRO\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:545: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...
